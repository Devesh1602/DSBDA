# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-8-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df.median()
# Out:
# <ipython-input-11-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
df.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
df.std()
# Out:
# <ipython-input-13-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
df.var()
# Out:
# <ipython-input-14-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Id               1887.500000
# SepalLengthCm       0.685694
# SepalWidthCm        0.188004
# PetalLengthCm       3.113179
# PetalWidthCm        0.582414
# dtype: float64

# %%
df.skew()
# Out:
# <ipython-input-15-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# Id               0.000000
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %%
df.quantile(0.25) #percentile
# Out:
# <ipython-input-16-8176ac8ed26b>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.25) #percentile
# Id               38.25
# SepalLengthCm     5.10
# SepalWidthCm      2.80
# PetalLengthCm     1.60
# PetalWidthCm      0.30
# Name: 0.25, dtype: float64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.groupby(['Species']).mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
df.groupby(['Species']).median()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5            5.0           3.4           1.50
# Iris-versicolor   75.5            5.9           2.8           4.35
# Iris-virginica   125.5            6.5           3.0           5.55
#
#                  PetalWidthCm
# Species
# Iris-setosa               0.2
# Iris-versicolor           1.3
# Iris-virginica            2.0

# %%
df.groupby(['Species'])['PetalLengthCm'].mean()
# Out:
# Species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: PetalLengthCm, dtype: float64

# %%
df.groupby(['Species'])['PetalLengthCm'].median()
# Out:
# Species
# Iris-setosa        1.50
# Iris-versicolor    4.35
# Iris-virginica     5.55
# Name: PetalLengthCm, dtype: float64

# %% [markdown]
# #Information about Iris-Versicolor

# %%
Iris_Versicolor = df.loc[df.Species=='Iris-versicolor']

# %%
Iris_Versicolor.min()
# Out:
# Id                            51
# SepalLengthCm                4.9
# SepalWidthCm                 2.0
# PetalLengthCm                3.0
# PetalWidthCm                 1.0
# Species          Iris-versicolor
# dtype: object

# %%
Iris_Versicolor.max()
# Out:
# Id                           100
# SepalLengthCm                7.0
# SepalWidthCm                 3.4
# PetalLengthCm                5.1
# PetalWidthCm                 1.8
# Species          Iris-versicolor
# dtype: object

# %%
Iris_Versicolor.mean()
# Out:
# <ipython-input-21-8e35e354efbb>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Versicolor.mean()
# Id               75.500
# SepalLengthCm     5.936
# SepalWidthCm      2.770
# PetalLengthCm     4.260
# PetalWidthCm      1.326
# dtype: float64

# %%
Iris_Versicolor.median()
# Out:
# <ipython-input-22-c20c06c092a3>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Versicolor.median()
# Id               75.50
# SepalLengthCm     5.90
# SepalWidthCm      2.80
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
Iris_Versicolor.mode()
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    51            5.5           3.0            4.5           1.3
# 1    52            5.6           NaN            NaN           NaN
# 2    53            5.7           NaN            NaN           NaN
# 3    54            NaN           NaN            NaN           NaN
# 4    55            NaN           NaN            NaN           NaN
# 5    56            NaN           NaN            NaN           NaN
# 6    57            NaN           NaN            NaN           NaN
# 7    58            NaN           NaN            NaN           NaN
# 8    59            NaN           NaN            NaN           NaN
# 9    60            NaN           NaN            NaN           NaN
# 10   61            NaN           NaN            NaN           NaN
# 11   62            NaN           NaN            NaN           NaN
# 12   63            NaN           NaN            NaN           NaN
# ...

# %%
Iris_Versicolor.std()
# Out:
# <ipython-input-24-345e7088d0f1>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Versicolor.std()
# Id               14.577380
# SepalLengthCm     0.516171
# SepalWidthCm      0.313798
# PetalLengthCm     0.469911
# PetalWidthCm      0.197753
# dtype: float64

# %%
Iris_Versicolor.var()
# Out:
# <ipython-input-25-c2a439b3d480>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Versicolor.var()
# Id               212.500000
# SepalLengthCm      0.266433
# SepalWidthCm       0.098469
# PetalLengthCm      0.220816
# PetalWidthCm       0.039106
# dtype: float64

# %%
Iris_Versicolor.skew()
# Out:
# <ipython-input-26-50d5d45d55d9>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Versicolor.skew()
# Id               0.000000
# SepalLengthCm    0.105378
# SepalWidthCm    -0.362845
# PetalLengthCm   -0.606508
# PetalWidthCm    -0.031180
# dtype: float64

# %%
Iris_Versicolor.quantile(0.25)
# Out:
# <ipython-input-27-9abf62f6c4a3>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Versicolor.quantile(0.25)
# Id               63.250
# SepalLengthCm     5.600
# SepalWidthCm      2.525
# PetalLengthCm     4.000
# PetalWidthCm      1.200
# Name: 0.25, dtype: float64

# %% [markdown]
# #Information about Iris-Setosa

# %%
Iris_Setosa=df.loc[(df.Species=='Iris-setosa')]

# %%
Iris_Setosa.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.3
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
Iris_Setosa.max()
# Out:
# Id                        50
# SepalLengthCm            5.8
# SepalWidthCm             4.4
# PetalLengthCm            1.9
# PetalWidthCm             0.6
# Species          Iris-setosa
# dtype: object

# %%
Iris_Setosa.mean()
# Out:
# <ipython-input-31-4b7698d0700d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Setosa.mean()
# Id               25.500
# SepalLengthCm     5.006
# SepalWidthCm      3.418
# PetalLengthCm     1.464
# PetalWidthCm      0.244
# dtype: float64

# %%
Iris_Setosa.median()
# Out:
# <ipython-input-32-dd95218ac775>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Setosa.median()
# Id               25.5
# SepalLengthCm     5.0
# SepalWidthCm      3.4
# PetalLengthCm     1.5
# PetalWidthCm      0.2
# dtype: float64

# %%
Iris_Setosa.mode()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.0           3.4            1.5           0.2  Iris-setosa
# 1    2            5.1           NaN            NaN           NaN          NaN
# 2    3            NaN           NaN            NaN           NaN          NaN
# 3    4            NaN           NaN            NaN           NaN          NaN
# 4    5            NaN           NaN            NaN           NaN          NaN
# 5    6            NaN           NaN            NaN           NaN          NaN
# 6    7            NaN           NaN            NaN           NaN          NaN
# 7    8            NaN           NaN            NaN           NaN          NaN
# 8    9            NaN           NaN            NaN           NaN          NaN
# 9   10            NaN           NaN            NaN           NaN          NaN
# 10  11            NaN           NaN            NaN           NaN          NaN
# ...

# %%
Iris_Setosa.std()
# Out:
# <ipython-input-34-abc435b28411>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Setosa.std()
# Id               14.577380
# SepalLengthCm     0.352490
# SepalWidthCm      0.381024
# PetalLengthCm     0.173511
# PetalWidthCm      0.107210
# dtype: float64

# %%
Iris_Setosa.var()
# Out:
# <ipython-input-35-8c751d7034a5>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Setosa.var()
# Id               212.500000
# SepalLengthCm      0.124249
# SepalWidthCm       0.145180
# PetalLengthCm      0.030106
# PetalWidthCm       0.011494
# dtype: float64

# %%
Iris_Setosa.skew()
# Out:
# <ipython-input-36-5581b9228139>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Setosa.skew()
# Id               0.000000
# SepalLengthCm    0.120087
# SepalWidthCm     0.107053
# PetalLengthCm    0.071846
# PetalWidthCm     1.197243
# dtype: float64

# %%
Iris_Setosa.quantile(0.25)
# Out:
# <ipython-input-37-72dfd07f6ed5>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Setosa.quantile(0.25)
# Id               13.250
# SepalLengthCm     4.800
# SepalWidthCm      3.125
# PetalLengthCm     1.400
# PetalWidthCm      0.200
# Name: 0.25, dtype: float64

# %% [markdown]
# #Information about Iris-Virginica

# %%
Iris_Virginica=df.loc[(df.Species=='Iris-virginica')]

# %%
Iris_Virginica.min()
# Out:
# Id                          101
# SepalLengthCm               4.9
# SepalWidthCm                2.2
# PetalLengthCm               4.5
# PetalWidthCm                1.4
# Species          Iris-virginica
# dtype: object

# %%
Iris_Virginica.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                3.8
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
Iris_Virginica.mean()
# Out:
# <ipython-input-41-a5c73fa4ac91>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Virginica.mean()
# Id               125.500
# SepalLengthCm      6.588
# SepalWidthCm       2.974
# PetalLengthCm      5.552
# PetalWidthCm       2.026
# dtype: float64

# %%
Iris_Virginica.median()
# Out:
# <ipython-input-42-e12dd96938d0>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Virginica.median()
# Id               125.50
# SepalLengthCm      6.50
# SepalWidthCm       3.00
# PetalLengthCm      5.55
# PetalWidthCm       2.00
# dtype: float64

# %%
Iris_Virginica.mode()
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   101            6.3           3.0            5.1           1.8
# 1   102            NaN           NaN            NaN           NaN
# 2   103            NaN           NaN            NaN           NaN
# 3   104            NaN           NaN            NaN           NaN
# 4   105            NaN           NaN            NaN           NaN
# 5   106            NaN           NaN            NaN           NaN
# 6   107            NaN           NaN            NaN           NaN
# 7   108            NaN           NaN            NaN           NaN
# 8   109            NaN           NaN            NaN           NaN
# 9   110            NaN           NaN            NaN           NaN
# 10  111            NaN           NaN            NaN           NaN
# 11  112            NaN           NaN            NaN           NaN
# 12  113            NaN           NaN            NaN           NaN
# ...

# %%
Iris_Virginica.std()
# Out:
# <ipython-input-44-2c848ee3b6d9>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Virginica.std()
# Id               14.577380
# SepalLengthCm     0.635880
# SepalWidthCm      0.322497
# PetalLengthCm     0.551895
# PetalWidthCm      0.274650
# dtype: float64

# %%
Iris_Virginica.var()
# Out:
# <ipython-input-45-a1485c01df1d>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Virginica.var()
# Id               212.500000
# SepalLengthCm      0.404343
# SepalWidthCm       0.104004
# PetalLengthCm      0.304588
# PetalWidthCm       0.075433
# dtype: float64

# %%
Iris_Virginica.skew()
# Out:
# <ipython-input-46-ce974b6eaf41>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Virginica.skew()
# Id               0.000000
# SepalLengthCm    0.118015
# SepalWidthCm     0.365949
# PetalLengthCm    0.549445
# PetalWidthCm    -0.129477
# dtype: float64

# %%
Iris_Virginica.quantile(0.25)
# Out:
# <ipython-input-47-a2de9d4cd3da>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Iris_Virginica.quantile(0.25)
# Id               113.250
# SepalLengthCm      6.225
# SepalWidthCm       2.800
# PetalLengthCm      5.100
# PetalWidthCm       1.800
# Name: 0.25, dtype: float64
