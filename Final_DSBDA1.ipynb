# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes #df.dtypes['Id']
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.shape
# Out:
# (150, 6)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df[0:3] #slicing operator
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df.loc[0:7,['Id','SepalLengthCm']] #The loc() function is label based data selecting method
                                   # which means that we have to pass the name of the row or column which we want to select.
# Out:
#    Id  SepalLengthCm
# 0   1            5.1
# 1   2            4.9
# 2   3            4.7
# 3   4            4.6
# 4   5            5.0
# 5   6            5.4
# 6   7            4.6
# 7   8            5.0

# %%
df.iloc[0:7,1:3] #The iloc() function is an indexed-based selecting method 
                 #which means that we have to pass an integer index in the method to select a specific row/column.
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6
# 5            5.4           3.9
# 6            4.6           3.4

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# #HOW TO DEAL WITH NULL VALUES
#
# # Drop rows with any null values
# data.dropna(axis=0, inplace=True)
#
# # Drop columns with any null values
# data.dropna(axis=1, inplace=True)
#
# # Fill null values with mean of the column
# data['column_name'].fillna(data['column_name'].mean(), inplace=True)
#
# # Fill null values with median of the column
# data['column_name'].fillna(data['column_name'].median(), inplace=True)
#
# # Fill null values with mode of the column
# data['column_name'].fillna(data['column_name'].mode()[0], inplace=True)
#
# # Fill null values with a constant value
# data['column_name'].fillna('Unknown', inplace=True)
#
# # Forward fill null values (last known value)
# data.fillna(method='ffill', inplace=True)
#
# # Backward fill null values (next known value)
# data.fillna(method='bfill', inplace=True)
#
# When inplace = True , the data is modified in place, which means it will return nothing and the dataframe is now updated.

# %%
# Summarizing variable types
df.dtypes.value_counts()
# Out:
# float64    4
# int64      1
# object     1
# dtype: int64

# %% [markdown]
# #DATA FORMATTING
# Used to change data type of a column variable

# %%
df['SepalLengthCm']=df['SepalLengthCm'].astype('int')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# #DATA NORMALIZATION:
# Used to map nominal data into uniform scale i.e. (0 to 1).
# Also knowns as MIN-MAX SCALING

# %%
from sklearn import preprocessing

# %%
min_max_scaler=preprocessing.MinMaxScaler() #Creating a minimum and maximum processor object

# %%
x=df.iloc[0:10,0:5]
x
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1              5           3.5            1.4           0.2
# 1   2              4           3.0            1.4           0.2
# 2   3              4           3.2            1.3           0.2
# 3   4              4           3.1            1.5           0.2
# 4   5              5           3.6            1.4           0.2
# 5   6              5           3.9            1.7           0.4
# 6   7              4           3.4            1.4           0.3
# 7   8              5           3.4            1.5           0.2
# 8   9              4           2.9            1.4           0.2
# 9  10              4           3.1            1.5           0.1

# %%
#Create an object to transform the data to fit minmax processor
x_scaled=min_max_scaler.fit_transform(x)

# %%
#Run normalizer on dataframe
df_normalized=pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#           0    1    2     3         4
# 0  0.000000  1.0  0.6  0.25  0.333333
# 1  0.111111  0.0  0.1  0.25  0.333333
# 2  0.222222  0.0  0.3  0.00  0.333333
# 3  0.333333  0.0  0.2  0.50  0.333333
# 4  0.444444  1.0  0.7  0.25  0.333333
# 5  0.555556  1.0  1.0  1.00  1.000000
# 6  0.666667  0.0  0.5  0.25  0.666667
# 7  0.777778  1.0  0.5  0.50  0.333333
# 8  0.888889  0.0  0.0  0.25  0.333333
# 9  1.000000  0.0  0.2  0.50  0.000000

# %% [markdown]
#  Turn categorical variables into quantitative variables in Python.

# %% [markdown]
# #LABEL ENCODING

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
df['Species']=label_encoder.fit_transform(df['Species'])

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# #ONE HOT ENCODING
# We create a dummy variable which is equal to no. of categories in that variable

# %%
enc=preprocessing.OneHotEncoder()

# %%
pd.get_dummies(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1              5           3.5            1.4           0.2        0
# 1      2              4           3.0            1.4           0.2        0
# 2      3              4           3.2            1.3           0.2        0
# 3      4              4           3.1            1.5           0.2        0
# 4      5              5           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146              6           3.0            5.2           2.3        2
# 146  147              6           2.5            5.0           1.9        2
# 147  148              6           3.0            5.2           2.0        2
# 148  149              6           3.4            5.4           2.3        2
# 149  150              5           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]
